# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

# %%
a = np.array(Image.open(r'C:\Users\Kevnn\GroupProject\physics-group-project\Task1_figure.png'))[:100,200:400]
z=a[tuple(50+i%49 for i in range(99)),None][:,:,tuple(50+i%49 for i in range(99)),None].reshape((99,99,4))
plt.imshow(z)
print(z.shape)

import itertools
[[None,i] for i in range(9)].
# Out:
#   Cell In[56], line 6
#     [None,i for i in range(9)]
#      ^
# SyntaxError: did you forget parentheses around the comprehension target?

# %%
for i in range(9):
    pass
else:
    print('hi')
print('ok')
# Out:
# hi
# ok

# %%
plt.imshow(np.broadcast_to(
    a[:,None,:,None,:,None],
    (100, 10, 200, 10, 4,1)) .reshape(1000, 2000,4))

# %%
import numpy as np

def match_shapes(f1: np.ndarray, f2: np.ndarray):
    f1 = np.array(f1)
    f2 = np.array(f2)

    

# Example usage:
a = np.array([[1, 2], [3, 4],[1,1]])  # Shape (2,2)
b = np.array([[5, 6],[3,2]])            # Shape (2,)

f1, f2 = match_shapes(a, b)
print(f1)
print(f2)
# Out:
# [[1 2]
#  [3 4]
#  [1 1]]
# [[5 6]
#  [3 2]
#  [5 6]]
