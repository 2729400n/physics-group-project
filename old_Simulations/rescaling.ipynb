# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

# %%
a = np.array(Image.open('Task1_figure.png'))[:100,200:400]
plt.imshow(a)

# %%
np.array(a)
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [ 90,  90,  90, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [223, 223, 223, 255],
#         [ 10,  10,  10, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [129, 129, 129, 255],
#         [ 22,  22,  22, 255],
#         [ 46,  46,  46, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
plt.imshow(np.broadcast_to(a[:,None,:,None,:,None], (100, 10, 200, 10, 4,1)).reshape(1000, 2000,4))
